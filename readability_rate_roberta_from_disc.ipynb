# %%
import string
import copy
import time
# %matplotlib inline
import os
# os.listdir("../input/")
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
# os.system('pip install pytorch_pretrained_bert --no-index --find-links="../input/pytorch-pretrained-bert/pytorch_pretrained_bert" ')
from torch.utils.data import Dataset, TensorDataset, DataLoader, RandomSampler, SequentialSampler
# from transformers.models.bert.modeling_bert import BertPreTrainedModel, BertModel
from transformers import RobertaTokenizer

from transformers import RobertaModel, AdamW
from torch.optim import SGD
import random
from transformers import get_linear_schedule_with_warmup, get_cosine_schedule_with_warmup
from torch.optim.lr_scheduler import OneCycleLR, CosineAnnealingWarmRestarts
from torch.cuda.amp import GradScaler, autocast
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter
# from torch_lr_finder import LRFinder, TrainDataLoaderIter, ValDataLoaderIter


SEED = 42
BATCH_SIZE = 16
MAX_LENGTH = 321
ROBERTA_FP = '../input/roberta-base'
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
os.environ['PYTHONASSEED'] = str(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = True

# %%
# pip install torch-lr-finder

# %%
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
def children(m):
    return m if isinstance(m, (list, tuple)) else list(m.children())


def set_trainable_attr(m, b):
    m.trainable = b
    for p in m.parameters():
        p.requires_grad = b


def apply_leaf(m, f):
    c = children(m)
    if isinstance(m, nn.Module):
        f(m)
    if len(c) > 0:
        for l in c:
            apply_leaf(l, f)


def set_trainable(l, b):
    apply_leaf(l, lambda m: set_trainable_attr(m, b))

# %%
class RobertaForSequenceRegression(nn.Module):
    def __init__(self):
        super(RobertaForSequenceRegression, self).__init__()
        self.roberta = RobertaModel.from_pretrained(ROBERTA_FP)
        self.head = AttentionHead(self.roberta.config.hidden_size, self.roberta.config.hidden_size)
        self.dropout = nn.Dropout(self.roberta.config.hidden_dropout_prob)
        self.linear1 = nn.Linear(self.roberta.config.hidden_size, 256)
        self.relu = nn.ReLU()
        self.linear2 = nn.Linear(256, 1)

    def forward(self, ids,  attention_mask):
        pooled_output = self.roberta(input_ids=ids, attention_mask=attention_mask)[0]
        pooled_output = self.head(pooled_output)
        pooled_output = self.dropout(pooled_output)
        pooled_output = self.linear1(pooled_output)
        pooled_output = self.relu(pooled_output)
        outputs = self.linear2(pooled_output)
        return outputs.view(-1)

# %%
class AttentionHead(nn.Module):
    def __init__(self, in_features, hidden_dim):
        super().__init__()
        self.in_features = in_features
        self.middle_features = hidden_dim
        self.W = nn.Linear(in_features, hidden_dim)
        self.V = nn.Linear(hidden_dim, 1)
        self.out_features = hidden_dim

    def forward(self, features):
        att = torch.tanh(self.W(features))
        score = self.V(att)
        attention_weights = torch.softmax(score, dim=1)
        context_vector = attention_weights * features
        context_vector = torch.sum(context_vector, dim=1)

        return context_vector

# %%
def RMSELoss(outputs, targets):
    return torch.sqrt(nn.MSELoss()(outputs, targets))

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import KBinsDiscretizer

class regressor_stratified_cv:
    def __init__(self, n_splits = 10, n_repeats = 2, group_count = 10,
                 random_state = 0, strategy = 'quantile'):
        self.group_count = group_count
        self.strategy = strategy
        self.cvkwargs = dict(n_splits = n_splits, n_repeats = n_repeats, 
                             random_state = random_state)
        self.cv = RepeatedStratifiedKFold(**self.cvkwargs)
        self.discretizer = KBinsDiscretizer(n_bins = self.group_count, encode = 'ordinal',
                                            strategy = self.strategy)  
            
    def split(self, X, y, groups = None):
        kgroups=self.discretizer.fit_transform(y[:, None])[:, 0]
        return self.cv.split(X, kgroups, groups)
    
    def get_n_splits(self, X, y, groups = None):
        return self.cv.get_n_splits(X, y, groups)

# %%
def text_preprocessing(excerpt):
    
    # lower casing
    excerpt = excerpt.lower()

    # removal of punctuation
    excerpt = excerpt.translate(str.maketrans('', '', string.punctuation))

                
    return excerpt

# %%
# class CustomTrainIter(TrainDataLoaderIter):
#     def inputs_labels_from_batch(self, batch_data):
#         inputs = batch_data["ids"], batch_data["token_type_ids"], batch_data["mask"]
#         labels = batch_data["targets"] 
#         return  inputs, labels

# %%
# class ModelWrapper(nn.Module):
#     def __init__(self, model):
#         super(ModelWrapper, self).__init__()
#         self.model = model

#     def forward(self, inputs):
#         ids, token_type_ids, attention_mask = inputs
#         return self.model(ids=ids, token_type_ids=token_type_ids, attention_mask=attention_mask)

# %%
df = pd.read_csv('../input/commonlitreadabilityprize/train.csv')
df
# Out:
#              id                                          url_legal  \
# 0     c12129c31                                                NaN
# 1     85aa80a4c                                                NaN
# 2     b69ac6792                                                NaN
# 3     dd1000b26                                                NaN
# 4     37c1b32fb                                                NaN
# ...         ...                                                ...
# 2829  25ca8f498  https://sites.ehe.osu.edu/beyondpenguins/files...
# 2830  2c26db523  https://en.wikibooks.org/wiki/Wikijunior:The_E...
# 2831  cd19e2350  https://en.wikibooks.org/wiki/Wikijunior:The_E...
# 2832  15e2e9e7a  https://en.wikibooks.org/wiki/Geometry_for_Ele...
# 2833  5b990ba77  https://en.wikibooks.org/wiki/Wikijunior:Biolo...
#
#            license                                            excerpt  \
# 0              NaN  When the young people returned to the ballroom...
# 1              NaN  All through dinner time, Mrs. Fayre was somewh...
# 2              NaN  As Roger had predicted, the snow departed as q...
# 3              NaN  And outside before the palace a great garden w...
# 4              NaN  Once upon a time there were Three Bears who li...
# ...            ...                                                ...
# 2829  CC BY-SA 3.0  When you think of dinosaurs and where they liv...
# 2830  CC BY-SA 3.0  So what is a solid? Solids are usually hard be...
# 2831  CC BY-SA 3.0  The second state of matter we will discuss is ...
# 2832  CC BY-SA 3.0  Solids are shapes that you can actually touch....
# 2833  CC BY-SA 3.0  Animals are made of many cells. They eat thing...
#
#         target  standard_error
# 0    -0.340259        0.464009
# 1    -0.315372        0.480805
# 2    -0.580118        0.476676
# 3    -1.054013        0.450007
# 4     0.247197        0.510845
# ...        ...             ...
# 2829  1.711390        0.646900
# 2830  0.189476        0.535648
# 2831  0.255209        0.483866
# 2832 -0.215279        0.514128
# 2833  0.300779        0.512379
#
# [2834 rows x 6 columns]

# %%
df["text"] = df["excerpt"].apply(lambda x: text_preprocessing(x))

# %%
excerpts = df.text.values
targets = df.target.values

# %%
# Load the ROBERTA tokenizer.
tokenizer = RobertaTokenizer.from_pretrained(ROBERTA_FP)

# %%
class TokenDataset(Dataset):
    def __init__(self, tokenizer, text, target = None, is_test=False):
        self.text = text
        self.target = target
        self.is_test = is_test
        self.max_len = MAX_LENGTH
        self.tokenizer = tokenizer
        
    def __len__(self):
        return len(self.text)
    
    def __getitem__(self, idx):
        text = str(self.text[idx])
        text = ' '.join(text.split())
        inputs = self.tokenizer.encode_plus(
            text,
            truncation=True,
            add_special_tokens=True,
            max_length = self.max_len,
            padding='max_length',
#             add_special_tokens=True,
            return_attention_mask=True
        )
        ids = torch.tensor(inputs['input_ids'], dtype=torch.long)
        mask = torch.tensor(inputs['attention_mask'], dtype=torch.long)
        
        if self.is_test:
            return {
                'ids': ids,
                'mask': mask,
            }
        else:    
            targets = torch.tensor(self.target[idx], dtype=torch.float)
            return {
                'ids': ids,
                'mask': mask,
                'targets': targets
            }

# %%
writer = SummaryWriter()

# %%
# CUDA_LAUNCH_BLOCKING=1
# n_splits = 5
# n_repeats = 1
# group_count = 10

# cv = regressor_stratified_cv(n_splits = n_splits, n_repeats = n_repeats,
#                            group_count = group_count, random_state = 0, strategy = 'quantile')
# i = 1
# for train_idx, test_idx in cv.split(df["text"], df["target"].values):
#     train_data = df.loc[train_idx]
#     test_data = df.loc[test_idx]
    
# train_set = TokenDataset(tokenizer,
#                         text = train_data['text'].values,
#                         target = train_data['target'].values
#                         )

# train_dataloader = DataLoader(train_set, batch_size = BATCH_SIZE, shuffle = True, num_workers=8)
    
# custom_train_iter = CustomTrainIter(train_dataloader)
# criterion = nn.MSELoss()
# model = RobertaForSequenceRegression().to(device)
# model_wrapper = ModelWrapper(model)
# optimizer = SGD(model.parameters(), lr=2e-5, momentum=0.9)
# lr_finder = LRFinder(model_wrapper, optimizer, criterion, device)
# lr_finder.range_test(custom_train_iter, end_lr=1)
# lr_finder.plot()

# %%
n_splits = 5
n_repeats = 1
group_count = 10

cv = regressor_stratified_cv(n_splits = n_splits, n_repeats = n_repeats,
                           group_count = group_count, random_state = 0, strategy = 'quantile')

df = df[['text', 'target']]

epochs = 30
n_epochs_stop = 10
epochs_no_improve = 0
training_stats = []
i = 1
eval_losses = []
# scaler = GradScaler()
# input_ids, attention_masks, token_type_ids = encode(excerpts, tokenizer)
for train_idx, test_idx in cv.split(df["text"], df["target"].values):
    print('======== Fold {:}  ========'.format(i))
    train_data = df.loc[train_idx]
    test_data = df.loc[test_idx]
    
    train_set = TokenDataset(tokenizer,
                            text = train_data['text'].values,
                            target = train_data['target'].values
                           )
    
    test_set = TokenDataset(tokenizer,
                           text = test_data['text'].values,
                           target = test_data['target'].values
                          )

    train_dataloader = DataLoader(train_set, batch_size = BATCH_SIZE, shuffle = True, num_workers=8)

    test_dataloader = DataLoader(test_set, batch_size = BATCH_SIZE, shuffle = False, num_workers=8)
    
    model = RobertaForSequenceRegression().to(device)
#     set_trainable(model, True)
#     set_trainable(model.roberta.embeddings, False)
#     set_trainable(model.roberta.encoder, False)
    # Defining Optimizer with weight decay to params other than bias and layer norms
#     param_optimizer = list(model.named_parameters())
#     no_decay = ["bias", "LayerNorm.bias", "LayerNorm.weight"]
#     optimizer_parameters = [
#         {'params': [p for n, p in param_optimizer if not any(nd in n for nd in no_decay)], 
#          'weight_decay': 0.001},
#         {'params': [p for n, p in param_optimizer if any(nd in n for nd in no_decay)], 
#          'weight_decay': 0.0}
#     ]  
    optimizer = AdamW(model.parameters(),
                      lr = 2e-5,
                      weight_decay = 0.01
                     )
#     optimizer = SGD(model.parameters(), lr=2e-5, momentum=0.9)
    total_steps = (len(train_dataloader) * epochs)               
#     num_steps = int(total_steps * 0.1)
#     scheduler = CosineAnnealingWarmRestarts(optimizer, T_0 = 10, T_mult = 1)
#     scheduler = OneCycleLR(optimizer, max_lr=2e-5, steps_per_epoch=len(train_dataloader), epochs=epochs)
    iters = len(train_dataloader)
#     scheduler = get_linear_schedule_with_warmup(optimizer, 
#                                             num_warmup_steps = 0,
#                                             num_training_steps = total_steps)
    scheduler = get_cosine_schedule_with_warmup(optimizer,
                                                num_warmup_steps=0, 
                                                num_training_steps= total_steps)    
    iter_eval_loss = []
    min_eval_loss = np.Inf
    for epoch_i in range(0, epochs):
        print("")
        print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
        t0 = time.time()
        # training
        model.train()
        tr_loss = []
        for step, batch in enumerate(train_dataloader):
            ids = batch['ids'].to(device, dtype=torch.long)
            input_mask = batch['mask'].to(device, dtype=torch.long)
            target = batch['targets'].to(device, dtype=torch.float)
            optimizer.zero_grad()
            with autocast():
                output = model(ids, input_mask)
                loss = RMSELoss(output, target)
                tr_loss.append(loss.cpu().detach().numpy().tolist())

            loss.backward()
            optimizer.step()
            scheduler.step(epoch_i + step/ iters)
        
        torch.cuda.empty_cache()
        train_losses = np.mean(tr_loss)  
        training_time = format_time(time.time() - t0)
        writer.add_scalar(f"Loss/train_fold_{i}_epoch_{epoch_i+1}", train_losses, epoch_i)
        print("Train loss: ", train_losses)
        print("Training epcoh took: {:}".format(training_time))
        
        # evaluation
        t0 = time.time()
        all_targets, all_preds = [], []
        model.eval()   
        eval_loss = []
        
        # disable gradients 
        with torch.no_grad(): 
            for batch in test_dataloader:
                ids = batch['ids'].to(device, dtype=torch.long)
                input_mask = batch['mask'].to(device, dtype=torch.long)
                target = batch['targets'].to(device, dtype=torch.float)
                output = model(ids, input_mask)
                loss = RMSELoss(output, target)
                eval_loss.append(loss.cpu().detach().numpy().tolist())
            
        epoch_eval_loss = np.mean(eval_loss)
        eval_time = format_time(time.time() - t0)
        writer.add_scalar(f"Loss/eval_fold_{i}_epoch_{epoch_i+1}", epoch_eval_loss, epoch_i)
        print("Eval loss: ", epoch_eval_loss)
        print("Evaluation took: {:}".format(eval_time))
        
        # recording all statistics from this epoch
        training_stats.append({
            'fold' : i,
            'epoch': epoch_i + 1,
            'Training Loss': train_losses,
            'Eval Loss': epoch_eval_loss,
            'Training Time': training_time,
            'Eval Time': eval_time
        })
        
        # early stopping and saving best model
        if epoch_eval_loss < min_eval_loss:
            epochs_no_improve = 0
            min_eval_loss = epoch_eval_loss
            best_model = copy.deepcopy(model)
            PATH = f'model_fold_{i}_epoch_{epoch_i+1}_loss_{round(epoch_eval_loss, 3)}.pt'
        else:
            epochs_no_improve += 1
#         if epochs_no_improve >= n_epochs_stop:
#             print('Early stopping! Epoch {:}'.format(epoch_i + 1) )
#             break
#         else:
#             continue
    
    torch.save(best_model.state_dict(), PATH)    
    i += 1    
    torch.cuda.empty_cache()
writer.flush()
writer.close()
# Out:
# ======== Fold 1  ========
#
# ======== Epoch 1 / 30 ========
# Train loss:  0.701409744544768
# Training epcoh took: 0:01:28
# Eval loss:  0.5585486417015394
# Evaluation took: 0:00:08
#
# ======== Epoch 2 / 30 ========
# Train loss:  0.5105143075048084
# Training epcoh took: 0:01:26
# Eval loss:  0.6548760856191317
# Evaluation took: 0:00:08
#
# ======== Epoch 3 / 30 ========
# Train loss:  0.41737641562038746
# Training epcoh took: 0:01:26
# Eval loss:  0.5692031913333468
# Evaluation took: 0:00:08
#
# ======== Epoch 4 / 30 ========
# Train loss:  0.3340442480755524
# Training epcoh took: 0:01:27
# Eval loss:  0.6297457060880132
# Evaluation took: 0:00:08
#
# ======== Epoch 5 / 30 ========
# Train loss:  0.283736699903515
# Training epcoh took: 0:01:27
# Eval loss:  0.6148091620869107
# Evaluation took: 0:00:07
#
# ======== Epoch 6 / 30 ========
# Train loss:  0.23333332876504306
# Training epcoh took: 0:01:26
# Eval loss:  0.5754216445816888
# Evaluation took: 0:00:08
#
# ======== Epoch 7 / 30 ========
# Train loss:  0.21556355982599124
# Training epcoh took: 0:01:26
# Eval loss:  0.5448548189467854
# Evaluation took: 0:00:08
#
# ======== Epoch 8 / 30 ========
# Train loss:  0.19923021927685805
# Training epcoh took: 0:01:27
# Eval loss:  0.614159009522862
# Evaluation took: 0:00:08
#
# ======== Epoch 9 / 30 ========
# Train loss:  0.17156700107833028
# Training epcoh took: 0:01:26
# Eval loss:  0.5937884880436791
# Evaluation took: 0:00:08
#
# ======== Epoch 10 / 30 ========
# Train loss:  0.17040071966992298
# Training epcoh took: 0:01:27
# Eval loss:  0.6291394622789489
# Evaluation took: 0:00:08
#
# ======== Epoch 11 / 30 ========
# Train loss:  0.1523442901146244
# Training epcoh took: 0:01:27
# Eval loss:  0.5980260943373045
# Evaluation took: 0:00:07
#
# ======== Epoch 12 / 30 ========
# Train loss:  0.14451661254738418
# Training epcoh took: 0:01:27
# Eval loss:  0.6215930953621864
# Evaluation took: 0:00:08
#
# ======== Epoch 13 / 30 ========
# Train loss:  0.14529261139916702
# Training epcoh took: 0:01:27
# Eval loss:  0.5714318859908316
# Evaluation took: 0:00:08
#
# ======== Epoch 14 / 30 ========
# Train loss:  0.143890738329837
# Training epcoh took: 0:01:27
# Eval loss:  0.5710884084304174
# Evaluation took: 0:00:08
#
# ======== Epoch 15 / 30 ========
# Train loss:  0.1397867744762293
# Training epcoh took: 0:01:27
# Eval loss:  0.5911209094855521
# Evaluation took: 0:00:08
#
# ======== Epoch 16 / 30 ========
# Train loss:  0.1347047982501312
# Training epcoh took: 0:01:27
# Eval loss:  0.6013390314247873
# Evaluation took: 0:00:08
#
# ======== Epoch 17 / 30 ========
# Train loss:  0.13306793659715585
# Training epcoh took: 0:01:27
# Eval loss:  0.559543091389868
# Evaluation took: 0:00:08
#
# ======== Epoch 18 / 30 ========
# Train loss:  0.13027385071339742
# Training epcoh took: 0:01:27
# Eval loss:  0.6108146417472098
# Evaluation took: 0:00:08
#
# ======== Epoch 19 / 30 ========
# Train loss:  0.13057755106981372
# Training epcoh took: 0:01:27
# Eval loss:  0.5785744455125597
# Evaluation took: 0:00:08
#
# ======== Epoch 20 / 30 ========
# Train loss:  0.1287631761072807
# Training epcoh took: 0:01:26
# Eval loss:  0.5664356152216593
# Evaluation took: 0:00:08
#
# ======== Epoch 21 / 30 ========
# Train loss:  0.1274088900798643
# Training epcoh took: 0:01:26
# Eval loss:  0.6101149552398257
# Evaluation took: 0:00:08
#
# ======== Epoch 22 / 30 ========
# Train loss:  0.11790650282842173
# Training epcoh took: 0:01:27
# Eval loss:  0.5582478957043754
# Evaluation took: 0:00:08
#
# ======== Epoch 23 / 30 ========
# Train loss:  0.12299692489101853
# Training epcoh took: 0:01:26
# Eval loss:  0.5525000451339616
# Evaluation took: 0:00:08
#
# ======== Epoch 24 / 30 ========
# Train loss:  0.12534987139449993
# Training epcoh took: 0:01:26
# Eval loss:  0.6767989777856402
# Evaluation took: 0:00:08
#
# ======== Epoch 25 / 30 ========
# Train loss:  0.11770275586717566
# Training epcoh took: 0:01:26
# Eval loss:  0.5872908474670516
# Evaluation took: 0:00:08
#
# ======== Epoch 26 / 30 ========
# Train loss:  0.11798986357072709
# Training epcoh took: 0:01:26
# Eval loss:  0.5528655747572581
# Evaluation took: 0:00:08
#
# ======== Epoch 27 / 30 ========
# Train loss:  0.1110116217127988
# Training epcoh took: 0:01:27
# Eval loss:  0.5752527018388113
# Evaluation took: 0:00:08
#
# ======== Epoch 28 / 30 ========
# Train loss:  0.10717182716643306
# Training epcoh took: 0:01:27
# Eval loss:  0.5685354678167237
# Evaluation took: 0:00:07
#
# ======== Epoch 29 / 30 ========
# Train loss:  0.11205109250797353
# Training epcoh took: 0:01:26
# Eval loss:  0.5773893743753433
# Evaluation took: 0:00:08
#
# ======== Epoch 30 / 30 ========
# Train loss:  0.10440891490540874
# Training epcoh took: 0:01:26
# Eval loss:  0.572958242562082
# Evaluation took: 0:00:08
# ======== Fold 2  ========
#
# ======== Epoch 1 / 30 ========
# Train loss:  0.714539294721375
# Training epcoh took: 0:01:26
# Eval loss:  0.6082930333084531
# Evaluation took: 0:00:08
#
# ======== Epoch 2 / 30 ========
# Train loss:  0.5328370460741957
# Training epcoh took: 0:01:26
# Eval loss:  0.5571675822138786
# Evaluation took: 0:00:08
#
# ======== Epoch 3 / 30 ========
# Train loss:  0.4342871304129211
# Training epcoh took: 0:01:27
# Eval loss:  0.6017002968324555
# Evaluation took: 0:00:08
#
# ======== Epoch 4 / 30 ========
# Train loss:  0.3643605514941081
# Training epcoh took: 0:01:27
# Eval loss:  0.5812780583898226
# Evaluation took: 0:00:08
#
# ======== Epoch 5 / 30 ========
# Train loss:  0.2834299469078091
# Training epcoh took: 0:01:27
# Eval loss:  0.5718345865607262
# Evaluation took: 0:00:08
#
# ======== Epoch 6 / 30 ========
# Train loss:  0.24843141153244905
# Training epcoh took: 0:01:27
# Eval loss:  0.6049841576152377
# Evaluation took: 0:00:08
#
# ======== Epoch 7 / 30 ========
# Train loss:  0.20296053042714024
# Training epcoh took: 0:01:27
# Eval loss:  0.6053402970234553
# Evaluation took: 0:00:08
#
# ======== Epoch 8 / 30 ========
# Train loss:  0.19815276647117777
# Training epcoh took: 0:01:26
# Eval loss:  0.6337690494126744
# Evaluation took: 0:00:08
#
# ======== Epoch 9 / 30 ========
# Train loss:  0.1779889168978577
# Training epcoh took: 0:01:26
# Eval loss:  0.6069254618551996
# Evaluation took: 0:00:08
#
# ======== Epoch 10 / 30 ========
# Train loss:  0.1717133983235124
# Training epcoh took: 0:01:28
# Eval loss:  0.6505490624242358
# Evaluation took: 0:00:08
#
# ======== Epoch 11 / 30 ========
# Train loss:  0.1599000245332718
# Training epcoh took: 0:01:27
# Eval loss:  0.6260907567209668
# Evaluation took: 0:00:08
#
# ======== Epoch 12 / 30 ========
# Train loss:  0.14965735496559612
# Training epcoh took: 0:01:27
# Eval loss:  0.6344422209593985
# Evaluation took: 0:00:08
#
# ======== Epoch 13 / 30 ========
# Train loss:  0.1546902893189813
# Training epcoh took: 0:01:26
# Eval loss:  0.5515942896405855
# Evaluation took: 0:00:08
#
# ======== Epoch 14 / 30 ========
# Train loss:  0.14950582983208374
# Training epcoh took: 0:01:27
# Eval loss:  0.601061698463228
# Evaluation took: 0:00:08
#
# ======== Epoch 15 / 30 ========
# Train loss:  0.14180773145086328
# Training epcoh took: 0:01:27
# Eval loss:  0.6277603854735693
# Evaluation took: 0:00:08
#
# ======== Epoch 16 / 30 ========
# Train loss:  0.13019780206008696
# Training epcoh took: 0:01:27
# Eval loss:  0.5727326977584097
# Evaluation took: 0:00:08
#
# ======== Epoch 17 / 30 ========
# Train loss:  0.130520242568053
# Training epcoh took: 0:01:28
# Eval loss:  0.5658898908230994
# Evaluation took: 0:00:08
#
# ======== Epoch 18 / 30 ========
# Train loss:  0.12212008080432113
# Training epcoh took: 0:01:27
# Eval loss:  0.5693284041351743
# Evaluation took: 0:00:08
#
# ======== Epoch 19 / 30 ========
# Train loss:  0.12503012993805845
# Training epcoh took: 0:01:27
# Eval loss:  0.6044018111295171
# Evaluation took: 0:00:08
#
# ======== Epoch 20 / 30 ========
# Train loss:  0.11914594466207733
# Training epcoh took: 0:01:27
# Eval loss:  0.5914052642054028
# Evaluation took: 0:00:08
#
# ======== Epoch 21 / 30 ========
# Train loss:  0.12090234127892575
# Training epcoh took: 0:01:27
# Eval loss:  0.6430241175823741
# Evaluation took: 0:00:08
#
# ======== Epoch 22 / 30 ========
# Train loss:  0.1163412316269438
# Training epcoh took: 0:01:27
# Eval loss:  0.5818021148443222
# Evaluation took: 0:00:08
#
# ======== Epoch 23 / 30 ========
# Train loss:  0.11124588848209717
# Training epcoh took: 0:01:26
# Eval loss:  0.5710462199317085
# Evaluation took: 0:00:08
#
# ======== Epoch 24 / 30 ========
# Train loss:  0.11576345888241915
# Training epcoh took: 0:01:27
# Eval loss:  0.6035411159197489
# Evaluation took: 0:00:08
#
# ======== Epoch 25 / 30 ========
# Train loss:  0.11816792014304181
# Training epcoh took: 0:01:26
# Eval loss:  0.6035849675536156
# Evaluation took: 0:00:08
#
# ======== Epoch 26 / 30 ========
# Train loss:  0.1239192897690014
# Training epcoh took: 0:01:27
# Eval loss:  0.5748003034128083
# Evaluation took: 0:00:08
#
# ======== Epoch 27 / 30 ========
# Train loss:  0.11842878813474951
# Training epcoh took: 0:01:27
# Eval loss:  0.5746423850456873
# Evaluation took: 0:00:08
#
# ======== Epoch 28 / 30 ========
# Train loss:  0.11303988183048409
# Training epcoh took: 0:01:26
# Eval loss:  0.5979685584704081
# Evaluation took: 0:00:08
#
# ======== Epoch 29 / 30 ========
# Train loss:  0.11104799969725206
# Training epcoh took: 0:01:27
# Eval loss:  0.5784559696912766
# Evaluation took: 0:00:08
#
# ======== Epoch 30 / 30 ========
# Train loss:  0.10501849388992282
# Training epcoh took: 0:01:26
# Eval loss:  0.6020734326706992
# Evaluation took: 0:00:08
# ======== Fold 3  ========
#
# ======== Epoch 1 / 30 ========
# Train loss:  0.7090749115171567
# Training epcoh took: 0:01:26
# Eval loss:  0.5376033203469383
# Evaluation took: 0:00:08
#
# ======== Epoch 2 / 30 ========
# Train loss:  0.5089796554874366
# Training epcoh took: 0:01:26
# Eval loss:  0.7213474603162872
# Evaluation took: 0:00:08
#
# ======== Epoch 3 / 30 ========
# Train loss:  0.42903929329674007
# Training epcoh took: 0:01:27
# Eval loss:  0.5806819072200192
# Evaluation took: 0:00:08
#
# ======== Epoch 4 / 30 ========
# Train loss:  0.3333640772272164
# Training epcoh took: 0:01:26
# Eval loss:  0.5075102874802219
# Evaluation took: 0:00:08
#
# ======== Epoch 5 / 30 ========
# Train loss:  0.25910084369316905
# Training epcoh took: 0:01:26
# Eval loss:  0.6418635315365262
# Evaluation took: 0:00:08
#
# ======== Epoch 6 / 30 ========
# Train loss:  0.23574637600653608
# Training epcoh took: 0:01:26
# Eval loss:  0.6407215628359053
# Evaluation took: 0:00:08
#
# ======== Epoch 7 / 30 ========
# Train loss:  0.20640310267327536
# Training epcoh took: 0:01:27
# Eval loss:  0.6227826774120331
# Evaluation took: 0:00:08
#
# ======== Epoch 8 / 30 ========
# Train loss:  0.18513108370169787
# Training epcoh took: 0:01:26
# Eval loss:  0.5644083056184981
# Evaluation took: 0:00:08
#
# ======== Epoch 9 / 30 ========
# Train loss:  0.17899907149479422
# Training epcoh took: 0:01:26
# Eval loss:  0.5807600186930763
# Evaluation took: 0:00:08
#
# ======== Epoch 10 / 30 ========
# Train loss:  0.1628651968924932
# Training epcoh took: 0:01:26
# Eval loss:  0.5784746590587828
# Evaluation took: 0:00:08
#
# ======== Epoch 11 / 30 ========
# Train loss:  0.1626137191246093
# Training epcoh took: 0:01:26
# Eval loss:  0.5695979504121674
# Evaluation took: 0:00:08
#
# ======== Epoch 12 / 30 ========
# Train loss:  0.16250354518562976
# Training epcoh took: 0:01:26
# Eval loss:  0.584713543454806
# Evaluation took: 0:00:08
#
# ======== Epoch 13 / 30 ========
# Train loss:  0.1409535062250117
# Training epcoh took: 0:01:26
# Eval loss:  0.5854154775540034
# Evaluation took: 0:00:08
#
# ======== Epoch 14 / 30 ========
# Train loss:  0.13996589540595739
# Training epcoh took: 0:01:26
# Eval loss:  0.5615996511446105
# Evaluation took: 0:00:08
#
# ======== Epoch 15 / 30 ========
# Train loss:  0.1415258486505965
# Training epcoh took: 0:01:27
# Eval loss:  0.5540033529202143
# Evaluation took: 0:00:08
#
# ======== Epoch 16 / 30 ========
# Train loss:  0.13572753456906533
# Training epcoh took: 0:01:27
# Eval loss:  0.5546908701459566
# Evaluation took: 0:00:08
#
# ======== Epoch 17 / 30 ========
# Train loss:  0.13128405127307058
# Training epcoh took: 0:01:27
# Eval loss:  0.5895495406455464
# Evaluation took: 0:00:08
#
# ======== Epoch 18 / 30 ========
# Train loss:  0.12166928499937057
# Training epcoh took: 0:01:27
# Eval loss:  0.5789836256040467
# Evaluation took: 0:00:08
#
# ======== Epoch 19 / 30 ========
# Train loss:  0.1258399260925575
# Training epcoh took: 0:01:27
# Eval loss:  0.5169878395067321
# Evaluation took: 0:00:08
#
# ======== Epoch 20 / 30 ========
# Train loss:  0.12311498435135458
# Training epcoh took: 0:01:27
# Eval loss:  0.5907472728027238
# Evaluation took: 0:00:08
#
# ======== Epoch 21 / 30 ========
# Train loss:  0.12102957972338502
# Training epcoh took: 0:01:27
# Eval loss:  0.5403854159845246
# Evaluation took: 0:00:08
#
# ======== Epoch 22 / 30 ========
# Train loss:  0.12491183832917414
# Training epcoh took: 0:01:27
# Eval loss:  0.5765834111306403
# Evaluation took: 0:00:08
#
# ======== Epoch 23 / 30 ========
# Train loss:  0.11299722471182615
# Training epcoh took: 0:01:27
# Eval loss:  0.5401885923412111
# Evaluation took: 0:00:08
#
# ======== Epoch 24 / 30 ========
# Train loss:  0.10723718531219892
# Training epcoh took: 0:01:27
# Eval loss:  0.5660638370447688
# Evaluation took: 0:00:08
#
# ======== Epoch 25 / 30 ========
# Train loss:  0.1098759956920231
# Training epcoh took: 0:01:27
# Eval loss:  0.5597292251057095
# Evaluation took: 0:00:08
#
# ======== Epoch 26 / 30 ========
# Train loss:  0.11131387673528262
# Training epcoh took: 0:01:27
# Eval loss:  0.564890581700537
# Evaluation took: 0:00:08
#
# ======== Epoch 27 / 30 ========
# Train loss:  0.11123251849391931
# Training epcoh took: 0:01:27
# Eval loss:  0.555053266386191
# Evaluation took: 0:00:08
#
# ======== Epoch 28 / 30 ========
# Train loss:  0.10881454529057086
# Training epcoh took: 0:01:27
# Eval loss:  0.5418119269112746
# Evaluation took: 0:00:08
#
# ======== Epoch 29 / 30 ========
# Train loss:  0.10936968380086859
# Training epcoh took: 0:01:27
# Eval loss:  0.580839936931928
# Evaluation took: 0:00:08
#
# ======== Epoch 30 / 30 ========
# Train loss:  0.10726468191600182
# Training epcoh took: 0:01:26
# Eval loss:  0.5482034393482738
# Evaluation took: 0:00:08
# ======== Fold 4  ========
#
# ======== Epoch 1 / 30 ========
# Train loss:  0.7149978840435055
# Training epcoh took: 0:01:26
# Eval loss:  0.6335457944207721
# Evaluation took: 0:00:08
#
# ======== Epoch 2 / 30 ========
# Train loss:  0.5262332252213653
# Training epcoh took: 0:01:27
# Eval loss:  0.6574947701560127
# Evaluation took: 0:00:08
#
# ======== Epoch 3 / 30 ========
# Train loss:  0.4277057066349916
# Training epcoh took: 0:01:27
# Eval loss:  0.5636322043008275
# Evaluation took: 0:00:08
#
# ======== Epoch 4 / 30 ========
# Train loss:  0.337647064051158
# Training epcoh took: 0:01:26
# Eval loss:  0.5216797068715096
# Evaluation took: 0:00:08
#
# ======== Epoch 5 / 30 ========
# Train loss:  0.2759126624171163
# Training epcoh took: 0:01:27
# Eval loss:  0.6780258640646935
# Evaluation took: 0:00:08
#
# ======== Epoch 6 / 30 ========
# Train loss:  0.23810552186529402
# Training epcoh took: 0:01:27
# Eval loss:  0.5414615347981453
# Evaluation took: 0:00:08
#
# ======== Epoch 7 / 30 ========
# Train loss:  0.21840167313184536
# Training epcoh took: 0:01:27
# Eval loss:  0.539670762916406
# Evaluation took: 0:00:08
#
# ======== Epoch 8 / 30 ========
# Train loss:  0.19266408398537568
# Training epcoh took: 0:01:27
# Eval loss:  0.5471710314353307
# Evaluation took: 0:00:08
#
# ======== Epoch 9 / 30 ========
# Train loss:  0.1892356553547819
# Training epcoh took: 0:01:27
# Eval loss:  0.6329837350381745
# Evaluation took: 0:00:08
#
# ======== Epoch 10 / 30 ========
# Train loss:  0.17794256006747905
# Training epcoh took: 0:01:27
# Eval loss:  0.5315583364831077
# Evaluation took: 0:00:08
#
# ======== Epoch 11 / 30 ========
# Train loss:  0.158340631551306
# Training epcoh took: 0:01:27
# Eval loss:  0.5725179256664382
# Evaluation took: 0:00:08
#
# ======== Epoch 12 / 30 ========
# Train loss:  0.16599248979293124
# Training epcoh took: 0:01:27
# Eval loss:  0.5684223787652122
# Evaluation took: 0:00:08
#
# ======== Epoch 13 / 30 ========
# Train loss:  0.1457520838249737
# Training epcoh took: 0:01:27
# Eval loss:  0.5162674983342489
# Evaluation took: 0:00:08
#
# ======== Epoch 14 / 30 ========
# Train loss:  0.14366433050640873
# Training epcoh took: 0:01:27
# Eval loss:  0.5421691719028685
# Evaluation took: 0:00:08
#
# ======== Epoch 15 / 30 ========
# Train loss:  0.14077120835722332
# Training epcoh took: 0:01:26
# Eval loss:  0.5446504809790187
# Evaluation took: 0:00:08
#
# ======== Epoch 16 / 30 ========
# Train loss:  0.14123428985476494
# Training epcoh took: 0:01:27
# Eval loss:  0.5238491040137079
# Evaluation took: 0:00:08
#
# ======== Epoch 17 / 30 ========
# Train loss:  0.13954574782663667
# Training epcoh took: 0:01:27
# Eval loss:  0.6244355779555109
# Evaluation took: 0:00:08
#
# ======== Epoch 18 / 30 ========
# Train loss:  0.13043049659947276
# Training epcoh took: 0:01:27
# Eval loss:  0.5469792005088594
# Evaluation took: 0:00:08
#
# ======== Epoch 19 / 30 ========
# Train loss:  0.12769083618383173
# Training epcoh took: 0:01:26
# Eval loss:  0.5143210598164134
# Evaluation took: 0:00:08
#
# ======== Epoch 20 / 30 ========
# Train loss:  0.12426935372428155
# Training epcoh took: 0:01:27
# Eval loss:  0.5649323273036215
# Evaluation took: 0:00:08
#
# ======== Epoch 21 / 30 ========
# Train loss:  0.1209212314389961
# Training epcoh took: 0:01:26
# Eval loss:  0.5531724989414215
# Evaluation took: 0:00:08
#
# ======== Epoch 22 / 30 ========
# Train loss:  0.12372220365304343
# Training epcoh took: 0:01:27
# Eval loss:  0.5089666412936317
# Evaluation took: 0:00:08
#
# ======== Epoch 23 / 30 ========
# Train loss:  0.12208711203764862
# Training epcoh took: 0:01:26
# Eval loss:  0.5420073610213068
# Evaluation took: 0:00:08
#
# ======== Epoch 24 / 30 ========
# Train loss:  0.11943978113187871
# Training epcoh took: 0:01:27
# Eval loss:  0.534974777036243
# Evaluation took: 0:00:08
#
# ======== Epoch 25 / 30 ========
# Train loss:  0.11763139950557494
# Training epcoh took: 0:01:26
# Eval loss:  0.5790116414427757
# Evaluation took: 0:00:08
#
# ======== Epoch 26 / 30 ========
# Train loss:  0.11980828432969644
# Training epcoh took: 0:01:27
# Eval loss:  0.5711900136537023
# Evaluation took: 0:00:09
#
# ======== Epoch 27 / 30 ========
# Train loss:  0.11436396915937813
# Training epcoh took: 0:01:26
# Eval loss:  0.527709054450194
# Evaluation took: 0:00:08
#
# ======== Epoch 28 / 30 ========
# Train loss:  0.11194764757135385
# Training epcoh took: 0:01:26
# Eval loss:  0.5648777633905411
# Evaluation took: 0:00:08
#
# ======== Epoch 29 / 30 ========
# Train loss:  0.10799926842077517
# Training epcoh took: 0:01:27
# Eval loss:  0.5418596466382345
# Evaluation took: 0:00:08
#
# ======== Epoch 30 / 30 ========
# Train loss:  0.10817964645233792
# Training epcoh took: 0:01:27
# Eval loss:  0.553268233107196
# Evaluation took: 0:00:08
# ======== Fold 5  ========
#
# ======== Epoch 1 / 30 ========
# Train loss:  0.7349420689361196
# Training epcoh took: 0:01:27
# Eval loss:  0.5761556633644633
# Evaluation took: 0:00:08
#
# ======== Epoch 2 / 30 ========
# Train loss:  0.5237911328883238
# Training epcoh took: 0:01:26
# Eval loss:  0.5883332416415215
# Evaluation took: 0:00:08
#
# ======== Epoch 3 / 30 ========
# Train loss:  0.4275783098919291
# Training epcoh took: 0:01:27
# Eval loss:  0.6947975903749466
# Evaluation took: 0:00:08
#
# ======== Epoch 4 / 30 ========
# Train loss:  0.3294782985893773
# Training epcoh took: 0:01:27
# Eval loss:  0.5765907044212023
# Evaluation took: 0:00:08
#
# ======== Epoch 5 / 30 ========
# Train loss:  0.2783647950896075
# Training epcoh took: 0:01:27
# Eval loss:  0.5610086652967665
# Evaluation took: 0:00:08
#
# ======== Epoch 6 / 30 ========
# Train loss:  0.236850467366232
# Training epcoh took: 0:01:27
# Eval loss:  0.5669930552442869
# Evaluation took: 0:00:08
#
# ======== Epoch 7 / 30 ========
# Train loss:  0.21087582147037479
# Training epcoh took: 0:01:27
# Eval loss:  0.5565295269091924
# Evaluation took: 0:00:08
#
# ======== Epoch 8 / 30 ========
# Train loss:  0.1936988503160611
# Training epcoh took: 0:01:27
# Eval loss:  0.5745976169904073
# Evaluation took: 0:00:08
#
# ======== Epoch 9 / 30 ========
# Train loss:  0.17565800674574475
# Training epcoh took: 0:01:27
# Eval loss:  0.5540305152535439
# Evaluation took: 0:00:08
#
# ======== Epoch 10 / 30 ========
# Train loss:  0.1678849570453167
# Training epcoh took: 0:01:27
# Eval loss:  0.5824977258841196
# Evaluation took: 0:00:08
#
# ======== Epoch 11 / 30 ========
# Train loss:  0.16302894381150393
# Training epcoh took: 0:01:27
# Eval loss:  0.6731138038966391
# Evaluation took: 0:00:08
#
# ======== Epoch 12 / 30 ========
# Train loss:  0.1476213186454605
# Training epcoh took: 0:01:27
# Eval loss:  0.5554200046592288
# Evaluation took: 0:00:09
#
# ======== Epoch 13 / 30 ========
# Train loss:  0.14609987094578608
# Training epcoh took: 0:01:27
# Eval loss:  0.5533351575334867
# Evaluation took: 0:00:08
#
# ======== Epoch 14 / 30 ========
# Train loss:  0.14721403711698425
# Training epcoh took: 0:01:27
# Eval loss:  0.5988696681128608
# Evaluation took: 0:00:08
#
# ======== Epoch 15 / 30 ========
# Train loss:  0.13827264791643115
# Training epcoh took: 0:01:27
# Eval loss:  0.5906515816847483
# Evaluation took: 0:00:08
#
# ======== Epoch 16 / 30 ========
# Train loss:  0.13034516735605792
# Training epcoh took: 0:01:27
# Eval loss:  0.5615129280421469
# Evaluation took: 0:00:08
#
# ======== Epoch 17 / 30 ========
# Train loss:  0.13206268673841381
# Training epcoh took: 0:01:27
# Eval loss:  0.6082780791653527
# Evaluation took: 0:00:08
#
# ======== Epoch 18 / 30 ========
# Train loss:  0.12701994642405443
# Training epcoh took: 0:01:27
# Eval loss:  0.6301882308390405
# Evaluation took: 0:00:08
#
# ======== Epoch 19 / 30 ========
# Train loss:  0.12307759112035724
# Training epcoh took: 0:01:27
# Eval loss:  0.5687060828010241
# Evaluation took: 0:00:08
#
# ======== Epoch 20 / 30 ========
# Train loss:  0.12469626601103326
# Training epcoh took: 0:01:27
# Eval loss:  0.5650740654932128
# Evaluation took: 0:00:08
#
# ======== Epoch 21 / 30 ========
# Train loss:  0.12096012619809365
# Training epcoh took: 0:01:27
# Eval loss:  0.5530305347508855
# Evaluation took: 0:00:08
#
# ======== Epoch 22 / 30 ========
# Train loss:  0.11550501497908378
# Training epcoh took: 0:01:27
# Eval loss:  0.5745854261848662
# Evaluation took: 0:00:08
#
# ======== Epoch 23 / 30 ========
# Train loss:  0.12557360949650617
# Training epcoh took: 0:01:27
# Eval loss:  0.6200807640949885
# Evaluation took: 0:00:08
#
# ======== Epoch 24 / 30 ========
# Train loss:  0.11968327670449942
# Training epcoh took: 0:01:27
# Eval loss:  0.5844642942150434
# Evaluation took: 0:00:08
#
# ======== Epoch 25 / 30 ========
# Train loss:  0.11671922980269915
# Training epcoh took: 0:01:27
# Eval loss:  0.5341448626584477
# Evaluation took: 0:00:08
#
# ======== Epoch 26 / 30 ========
# Train loss:  0.11249444455328123
# Training epcoh took: 0:01:27
# Eval loss:  0.5739914824565252
# Evaluation took: 0:00:08
#
# ======== Epoch 27 / 30 ========
# Train loss:  0.10961645587124455
# Training epcoh took: 0:01:27
# Eval loss:  0.601689912378788
# Evaluation took: 0:00:08
#
# ======== Epoch 28 / 30 ========
# Train loss:  0.1136172259567489
# Training epcoh took: 0:01:27
# Eval loss:  0.5996607608265347
# Evaluation took: 0:00:08
#
# ======== Epoch 29 / 30 ========
# Train loss:  0.10906015672314336
# Training epcoh took: 0:01:27
# Eval loss:  0.5702432600988282
# Evaluation took: 0:00:08
#
# ======== Epoch 30 / 30 ========
# Train loss:  0.10336406253488131
# Training epcoh took: 0:01:27
# Eval loss:  0.5475083109405305
# Evaluation took: 0:00:08

# %%
# Create a DataFrame from our training statistics.
df_stats = pd.DataFrame(data=training_stats)

# Use the 'fold' as the row index.
# df_stats = df_stats.set_index('fold')
df_stats
# Out:
#      fold  epoch  Training Loss  Eval Loss Training Time Eval Time
# 0       1      1       0.701410   0.558549       0:01:28   0:00:08
# 1       1      2       0.510514   0.654876       0:01:26   0:00:08
# 2       1      3       0.417376   0.569203       0:01:26   0:00:08
# 3       1      4       0.334044   0.629746       0:01:27   0:00:08
# 4       1      5       0.283737   0.614809       0:01:27   0:00:07
# ..    ...    ...            ...        ...           ...       ...
# 145     5     26       0.112494   0.573991       0:01:27   0:00:08
# 146     5     27       0.109616   0.601690       0:01:27   0:00:08
# 147     5     28       0.113617   0.599661       0:01:27   0:00:08
# 148     5     29       0.109060   0.570243       0:01:27   0:00:08
# 149     5     30       0.103364   0.547508       0:01:27   0:00:08
#
# [150 rows x 6 columns]

# %%
fig = plt.figure(figsize=(10, 15))
for fold in df_stats.fold.unique():
    ax = fig.add_subplot(5,1,fold)
    max_epoch = df_stats[df_stats['fold']==fold]['epoch'].max()
    x = np.arange(max_epoch)
    ax.plot(x,df_stats[df_stats['fold']==fold][['Training Loss']])
    ax.plot(x,df_stats[df_stats['fold']==fold][['Eval Loss']])
    plt.xticks(range(0, max_epoch, 5))

# %%
# n_splits = 5
# n_repeats = 2
# group_count = 10
# cv = regressor_stratified_cv(n_splits = n_splits, n_repeats = n_repeats,
#                            group_count = group_count, random_state = 0, strategy = 'quantile')

# for train_index, test_index in cv.split(input_ids, targets):
#     train_inputs, test_inputs = input_ids[train_index], input_ids[test_index]
#     train_targets, test_targets = targets[train_index], targets[test_index]
#     train_masks, test_masks = attention_masks[train_index], attention_masks[test_index]
#     train_type_ids, test_type_ids = token_type_ids[train_index], token_type_ids[test_index]

# %%
# train_inputs = torch.tensor(train_inputs, dtype=torch.long)
# test_inputs = torch.tensor(test_inputs, dtype=torch.long)
# train_targets = torch.tensor(train_targets, dtype=torch.float)
# test_targets = torch.tensor(test_targets, dtype=torch.float)
# train_masks = torch.tensor(train_masks, dtype=torch.long)
# test_masks = torch.tensor(test_masks, dtype=torch.long)
# train_type_ids = torch.tensor(train_type_ids, dtype=torch.long)
# test_type_ids = torch.tensor(test_type_ids, dtype=torch.long)

# %%
# train_data = TensorDataset(train_inputs, train_masks, train_type_ids, train_targets)
# train_sampler = RandomSampler(train_data)
# train_dataloader = DataLoader(train_data, sampler = train_sampler, batch_size = BATCH_SIZE)

# test_data = TensorDataset(test_inputs, test_masks, test_type_ids, test_targets)
# test_sampler = RandomSampler(test_data)
# test_dataloader = DataLoader(test_data, sampler = test_sampler, batch_size = BATCH_SIZE)

# %%
# set_trainable(model, True)
# set_trainable(model.bert.embeddings, True)    
# set_trainable(model.bert.encoder, True)

# %%
# epochs = 5
# optimizer = AdamW(model.parameters(),
#                   lr = 5e-6,
#                   eps = 1e-6 
#                 )
# total_steps = len(train_dataloader) * epochs
# scheduler = get_linear_schedule_with_warmup(optimizer, 
#                                             num_warmup_steps = 0,
#                                             num_training_steps = total_steps)
# eval_losses = []
# for epoch_i in range(0, epochs):
#     print("")
#     print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
#     # training
#     model.train()
#     tr_loss = []
    
#     for step, batch in enumerate(train_dataloader):
#         batch = tuple(t.to(device) for t in batch)
#         ids, input_mask, type_ids, target = batch
#         output = model(ids, input_mask, type_ids, target)
#         loss = RMSELoss(output, target)
#         tr_loss.append(loss.cpu().detach().numpy().tolist())
#         loss.backward()  
#         optimizer.step()
#         optimizer.zero_grad()  
#         scheduler.step()
            
#     train_losses = np.mean(tr_loss)  
#     print("Train loss: ", train_losses)
#     all_targets, all_preds = [], []
#     model.eval()   
#     eval_loss = []
#     # evaluation
#     # disable gradients 
#     with torch.no_grad(): 
#         for batch in test_dataloader:
#             batch = tuple(t.to(device) for t in batch)
#             ids, input_mask, type_ids, target = batch
#             output = model(ids, input_mask, type_ids, target)
#             loss = RMSELoss(output, target)
#         eval_loss.append(loss.cpu().detach().numpy().tolist())
            
#     epoch_eval_loss = np.mean(eval_loss)
#     print("Eval loss: ", epoch_eval_loss)

#     eval_losses.append(epoch_eval_loss)   
# torch.cuda.empty_cache()
# mean_eval_loss = np.mean(eval_losses)
# print(mean_eval_loss)

# %%
# test = pd.read_csv('../input/commonlitreadabilityprize/test.csv')

# %%
# test["text"] = test["excerpt"].apply(lambda x: text_preprocessing(x))

# %%
# excerpts = test.text.values

# %%
# # convert sentences into tokens
# input_ids = [tokenizer.encode(excerpt, add_special_tokens = True, max_length = MAX_LENGTH,
#                               padding='max_length') for excerpt in excerpts]

# input_ids = np.array(input_ids)
# attention_masks = []
# # create a mask of 1 for all input tokens and 0 for all padding tokens
# attention_masks = [[float(i>0) for i in seq] for seq in input_ids]
# attention_masks = np.array(attention_masks)
# # create token type ids
# token_type_ids = [[0 for i in seq] for seq in input_ids]
# token_type_ids = np.array(token_type_ids)

# %%
# input_ids = torch.tensor(input_ids, dtype=torch.long)
# attention_masks = torch.tensor(attention_masks, dtype=torch.long)
# token_type_ids = torch.tensor(token_type_ids, dtype=torch.long)

# %%
# prediction_data = TensorDataset(input_ids, attention_masks, token_type_ids)
# prediction_sampler = SequentialSampler(prediction_data)
# prediction_dataloader = DataLoader(prediction_data, sampler=prediction_sampler, batch_size=BATCH_SIZE)

# %%
# model.eval()   
# predictions , true_labels = [], []
# # evaluation
# for batch in prediction_dataloader:
#     # disable gradients 
#     batch = tuple(t.to(device) for t in batch)
#     ids, input_mask, type_ids = batch
#     with torch.no_grad():    
#         output = model(ids, input_mask, type_ids) 
#     output = output.cpu().detach().numpy().tolist()
#     predictions += output

# %%
# submission = pd.DataFrame({'id':test['id'],'target':predictions})

# %%
# submission.to_csv('submission.csv',index=False)

# %%
# torch.cuda.empty_cache()
